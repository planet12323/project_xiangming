# %%
import pandas as pd
import numpy as np
from pyswarm import pso
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

# %%
#需要将神经网络模型文件，和数据表放到此py文件目录下
# 读取Excel文件
excel_file1 = "1117_load.xls"  # 负荷预测输入数据集
excel_file2 = "1117_temp.xls"  # 温度预测输入数据集，设定温度也在这里面
excel_file3 = "1117_weather.xls"  # 气象预报输入数据集
dataset1 = pd.read_excel(excel_file1, usecols="A:E", header=None)
dataset2 = pd.read_excel(excel_file2, usecols="A:H", header=None)
data3 = np.array(pd.read_excel(excel_file3, usecols="A", header=None))

# %%
# 数据归一化处理
scaler = MinMaxScaler()
data1_scaled = scaler.fit_transform(dataset1)
data2_scaled = scaler.fit_transform(dataset2)
# data3_scaled = scaler.fit_transform(dataset3)

# %%
#参数
batchsize = 1 #批处理大小，预测模型里是32
step = 5 #时间步数
loaddim = 5 #负荷预测模型输入维度
tempdim = 7 #温度预测模型输入维度
rows_to_predict = 10 #进行预测的迭代次数，序列长度为step，步长为1
nextTin = 0 #中间变量Tin(t+1)，具体数值不重要
Beta = 0.000008 #可变参数β
Alpha = 1-Beta #可变参数α

T_max, T_min = 22.89888889, 22.69222222 # Tin训练集 max=22.89888889，min=22.69222222
C_max, C_min = 1193.96, 1153.82 # Cooling训练集 max=1193.96，min=1153.82
nextTset = 23

# %%
# 加载负荷预测模型
loadmodel = tf.keras.models.load_model('1117_loadpred.keras')
# 加载温度预测模型
tempmodel = tf.keras.models.load_model('1117_temppred.keras')

# %%
################## 热泵能耗方程：##################
# 1号热泵：磁悬浮1
def PphCal1(Cooling1, nextTreturn, nextTout):
    return Cooling1 / (0.114064992 * Cooling1
                      + 9.86011205 * nextTreturn
                      - 0.394321578 * nextTout
                      + 0.0000450464015 * Cooling1 * Cooling1
                      - 0.00581368122 * Cooling1 * nextTreturn
                      - 0.000758651811 * Cooling1 * nextTout
                      - 0.326362421 * nextTreturn * nextTreturn
                     + 0.0184361005* nextTreturn * nextTout
                     + 0.00239640342 * nextTout * nextTout - 71.6350077532962)
power1 = PphCal1(173.34, 14.55, 37.91)
print(power1)

# 2号热泵：磁悬浮2
def PphCal2(Cooling2, nextTreturn, nextTout):
    return Cooling2 / ( - 0.031207272 * Cooling2
                      - 5.57093763 * nextTreturn
                      - 0.178609075 * nextTout
                      - 0.000140286197 * Cooling2 * Cooling2
                      + 0.0081496977 * Cooling2 * nextTreturn
                      - 0.000599404697 * Cooling2 * nextTout
                      + 0.150016223 * nextTreturn * nextTreturn
                     - 0.00555278723 * nextTreturn * nextTout
                     + 0.00426582024 * nextTout * nextTout + 48.815621285422)
power2 = PphCal2(191.78, 14.59, 37.91)
print(power2)

# 3号热泵：螺杆1

def PphCal3(Cooling3, nextTreturn, nextTout):
    return Cooling3 / (- 0.0565696352 * Cooling3
                      + 140.258199 * nextTreturn
                      + 0.297813736 * nextTout
                      - 0.000000512788461 * Cooling3 * Cooling3
                      + 0.00512409975 * Cooling3 * nextTreturn
                      - 0.000396810401 * Cooling3 * nextTout
                      - 5.00822474 * nextTreturn * nextTreturn
                     - 0.00851263147* nextTreturn * nextTout
                     - 0.000209590663 * nextTout * nextTout -986.272338515734)
'''
def PphCal3(Cooling3, nextTreturn, nextTout):
    return Cooling3 / (0.0108998754 * Cooling3
                      - 69.4648733 * nextTreturn
                      - 0.382184169 * nextTout
                      + 0.0000107828275 * Cooling3 * Cooling3
                      - 0.000685155745 * Cooling3 * nextTreturn
                      - 0.000287410665 * Cooling3 * nextTout
                      + 2.3373995 * nextTreturn * nextTreturn
                      + 0.0342744052* nextTreturn * nextTout
                      - 0.000282931457 * nextTout * nextTout + 516.111737024876)
'''                      
power3 = PphCal3(646.4, 14.31, 37.91)
print(power3)


# 4号热泵：螺杆2
def PphCal4(Cooling4, nextTreturn, nextTout):
    return Cooling4 / (- 0.0316576759 * Cooling4
                      - 9.98926426 * nextTreturn
                      + 0.0902543953 * nextTout
                      + 0.0000000479863189 * Cooling4 * Cooling4
                      + 0.00257982592 * Cooling4 * nextTreturn
                      - 0.0000778893844 * Cooling4 * nextTout
                      + 0.295875914 * nextTreturn * nextTreturn
                     - 0.00932111852 * nextTreturn * nextTout
                     + 0.000430676823 * nextTout * nextTout + 84.2195052674394)
power4 = PphCal4(587.45, 14.58, 37.91)
print(power4)
# Out:
# 60.19008805479266
# 62.70218705354646
# 256.330379316575
# 274.29993549338934

# %%
################## 水泵能耗方程：##################
# Pwp=0.0322*Volume*Volume-1.7627*Volume+26.2738
def PwpCal(Volume):
    return 0.0238* Volume* Volume - 5.27 * Volume + 306.7
pump = PwpCal(120)
print(pump)
# Out:
# 17.02000000000004

# %%
################## 负荷能量守恒方程：##################
# Cooling = (Treturn - Tsupply)* Volume*4.2/3.6
# 其中，
# 45=< Volume =<90
# 9=< Tsupply =<15
# 12.5=< Treturn =<16.5
# 且Tsupply < Treturn
def Constraint1(x, Cooling):
#   Cooling = 2 * (Cooling_screw + Cooling_maglev)
    nextTsupply, nextTreturn, nextVscrew, nextVmaglev= x
    return (Cooling == (nextTreturn - nextTsupply) * 2 * (nextVscrew + nextVmaglev) * 4.2 / 3.6) and nextTsupply < nextTreturn
# 如果有多个Volume，可以分别设置，但是在计算Cooling时要加和

# %%
################## 代价函数：##################
# J=α*(Tset-Tin)2+β(Php+Pwp)2
# 其中，α=0.5，β=0.5（α，β赋值后续需要调整，暂定均为0.5）
def Cost(x, Alpha, Beta, nextTset, nextTout, Cooling):
    nextTsupply, nextTreturn, nextVscrew, nextVmaglev= x
    Pwp = PwpCal(2 / 3 * (nextVscrew + nextVmaglev))
    Cooling_maglev = Cooling / 2 * nextVmaglev / (nextVscrew + nextVmaglev)
    Cooling_screw = Cooling / 2 - Cooling_maglev
    Php1 = PphCal1(Cooling_maglev,nextTreturn,nextTout)
    Php2 = PphCal2(Cooling_maglev, nextTreturn, nextTout)
    Php3 = PphCal4(Cooling_screw, nextTreturn, nextTout)
    Php4 = PphCal4(Cooling_screw, nextTreturn, nextTout)
    # tempdata = np.append(KnownParams, nextTsupply)
    # tempdata = np.insert(KnownParams, 6, nextTsupply, axis= 1) # 温度预测比负荷预测多一个参数，给加进去
    #[1,5,7]
    # tempinput = np.tile(tempdata, (5,1)).reshape((batchsize, step, tempdim))
    # tempdata = data2[: , 0:7]
    tempinput = tempdata.reshape((batchsize, step, tempdim)) # 二维数组按照神经网络模型reshape
    global nextTin  # 更新nextTin的值
    global nextTin_scaled  # 更新nextTin的值
    nextTin_scaled = tempmodel.predict(tempinput,verbose=0)[0][0] # 计算出来的nextTin是高维张量，需要取其中的元素作为值
    nextTin = nextTin_scaled * (T_max - T_min) + T_min #温度预测值反归一化
    cost = Alpha * (nextTset - nextTin)*(nextTset - nextTin) + Beta * (Php1 + Php2+ Php3+ Php4 + Pwp * 3) *  (Php1 + Php2+ Php3+ Php4 + Pwp * 3)
    # cost = Alpha * (23 - nextTin)*(23 - nextTin) + Beta * (Php1 + Php2+ Php3+ Php4 + Pwp * 3) *  (Php1 + Php2+ Php3+ Php4 + Pwp * 3)
    return cost
'''
def Tin_deNormalize(nextTin_scaled, data2):
    Tins =  data2[:, 2]
    T_max, T_min = max(Tins), min(Tins)
    nextTin = nextTin_scaled * (T_max - T_min) + T_min
    return nextTin
def Co_deNormalize(Cooling_scaled, data1):
    coolings = data1[:, 0]
    c_max, c_min = max(coolings), min(coolings)
    Cooling = Cooling_scaled * (c_max - c_min) + c_min
    return Cooling
'''
# Out:
# '\ndef Tin_deNormalize(nextTin_scaled, data2):\n    Tins =  data2[:, 2]\n    T_max, T_min = max(Tins), min(Tins)\n    nextTin = nextTin_scaled * (T_max - T_min) + T_min\n    return nextTin\ndef Co_deNormalize(Cooling_scaled, data1):\n    coolings = data1[:, 0]\n    c_max, c_min = max(coolings), min(coolings)\n    Cooling = Cooling_scaled * (c_max - c_min) + c_min\n    return Cooling\n'

# %%
if __name__ == '__main__':
    # tempred.summary()
    ####待求解参数####
    # x = [nextTsupply,nextTreturn,nextVolume]
    x = []
    #####待优化函数值####
    # f = cost()
    cf = []
    co = []
    tin = []
    sc1 = []
    ma1 = []
    sc2 = []
    ma2 = []
    pu =[]
    tot = []
    deltaT = []  # 新增：存储供回水温差
    # 迭代预测过程，已将本轮Cooling，Tin(t+1)应用到下轮预测中
    for i in range(rows_to_predict):
        print('滚动次数：', i)
        tempdata = data2_scaled[i:i+5, 0:7]
        loaddata = data1_scaled[i:i+5, 0:5]
        loadinput = loaddata.reshape((batchsize,step,loaddim))
        #[1,5,6]
        Cooling_scaled = loadmodel.predict(loadinput,verbose=0)[0][0]
        #Cooling = Co_deNormalize(Cooling_scaled, data1)
        Cooling = Cooling_scaled * (C_max - C_min) + C_min #负荷预测值反归一化
        nextTout = data3[i+5,0]
        # nextTset = np.array(dataset2)[i+5,7]
        lb = [11, 14.5, 110, 35] # 流量lower bound必须大于0，不然在负荷分配中不能作为分母
        ub = [12, 15.5, 180, 70] # nextTsupply, nextTreturn, nextVscrew, nextVmaglev
        Constraint_with_param = lambda x: Constraint1(x, Cooling)
        Cost_with_param = lambda x: Cost(x, Alpha, Beta, nextTset, nextTout, Cooling)
        xopt,fopt = pso(Cost_with_param, lb, ub, f_ieqcons=Constraint_with_param, minfunc=0.1, maxiter=50)
        #更新Cooling，Tin(t+1)
        data2_scaled[i+5,1] = Cooling_scaled*0.6 + data2_scaled[i+5,1]*0.4 # 更新温度预测输入参数中的t时刻冷量
        data2_scaled[i+6,6] = Cooling_scaled*0.6 + data2_scaled[i+6,6]*0.4 # 更新温度预测输入参数中的t-1时刻冷量
        data1_scaled[i+5,0] = Cooling_scaled*0.6 + data1_scaled[i+5,0]*0.4 # 更新负荷预测输入参数中的t时刻冷量
        data1_scaled[i+5,1] = nextTin_scaled*0.4 + data1_scaled[i+5,1]*0.6 # 更新负荷预测输入参数中的t时刻温度
        data2_scaled[i+5,2] = nextTin_scaled*0.4 + data2_scaled[i+5,2]*0.6 # 更新温度预测输入参数中的t时刻温度
        print('更新后的Cooling：', data2_scaled[i+5,1])
        cooling_maglev = Cooling / 2 * xopt[3] / (xopt[2] + xopt[3])
        cooling_screw =  Cooling / 2  - cooling_maglev
        volume_pump = 2 / 3 * (xopt[2] + xopt[3])
        power_screw1 = PphCal4(cooling_screw, xopt[1], nextTout)
        power_screw2 = PphCal4(cooling_screw, xopt[1], nextTout)
        power_maglev1 = PphCal1(cooling_maglev, xopt[1], nextTout)
        power_maglev2 = PphCal2(cooling_maglev, xopt[1], nextTout)
        power_pump = PwpCal(volume_pump)
        power_total = ( power_screw1 + power_maglev1 + power_screw2 + power_maglev2) + 3 * power_pump
        # 新增：计算供回水温差
        deltaT_current = xopt[1] - xopt[0]
        deltaT.append(deltaT_current)
        print('供温，回温，螺杆流量，磁悬浮流量:',xopt)
        print('供回水温差:', deltaT_current)  # 新增：打印供回水温差
        print('Cost:',fopt)
        print('总冷量：', Cooling)
        print('室温：', nextTin)
        print('螺杆功率：', power_screw1, power_screw2)
        print('磁悬浮功率：', power_maglev1, power_maglev2)
        print('水泵功率：', power_pump)
        print('总功率：', power_total)
        x.append(xopt)
        cf.append(fopt)
        co.append(Cooling)
        tin.append(nextTin)
        sc1.append(power_screw1)
        sc2.append(power_screw2)
        ma1.append(power_maglev1)
        ma2.append(power_maglev2)
        pu.append(power_pump)
        tot.append(power_total)
    print('最终优化结果：')
    print('Tsupply(t+1)，Treturn(t+1),Volume(t+1):',x)
    print('代价函数最优值：',cf)
    print('冷量变化：', co)
    print('室温：', tin)
    print('供回水温差变化：', deltaT)  # 新增：打印供回水温差变化
# Out:
# 滚动次数： 0
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.41370043458187955
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.4283606   14.50063856 110.          64.48543037]
# 供回水温差: 3.0722779551039388
# Cost: 2.0826880167100237
# 总冷量： 1168.0832257401944
# 室温： 22.790162760105268
# 螺杆功率： 182.8707297222994 182.8707297222994
# 磁悬浮功率： 42.53154548090515 49.38581038776665
# 水泵功率： 15.716715429873886
# 总功率： 504.8089616028922
# 滚动次数： 1
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.46744450106214686
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.2129626   14.5        110.65434249  57.29759279]
# 供回水温差: 3.2870374027489113
# Cost: 2.0944965094873313
# 总冷量： 1170.2120371210574
# 室温： 22.78499894380837
# 螺杆功率： 185.13954450505466 185.13954450505466
# 磁悬浮功率： 43.01680874404277 47.68626476134014
# 水泵功率： 15.00526339626532
# 总功率： 505.99795270428814
# 滚动次数： 2
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4283673700077003
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.26519754  14.5        110.71534291  50.85103161]
# 供回水温差: 3.2348024589388107
# Cost: 2.126033070676753
# 总冷量： 1169.8311103868484
# 室温： 22.78017499538697
# 螺杆功率： 186.98833312248976 186.98833312248976
# 磁悬浮功率： 43.36530237406577 46.731650619103235
# 水泵功率： 15.182538558851547
# 总功率： 509.62123491470317
# 滚动次数： 3
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4189087652423581
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.44706849  14.5        110.          65.33573732]
# 供回水温差: 3.0529315075021817
# Cost: 2.0607508653321616
# 总冷量： 1169.8316630613804
# 室温： 22.7761015451533
# 螺杆功率： 181.2710669611737 181.2710669611737
# 磁悬浮功率： 42.04480308280553 49.11173724145353
# 水泵功率： 15.875720483265184
# 总功率： 501.32583569640195
# 滚动次数： 4
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.47637544667239806
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.00329461  14.5        115.3760857   66.17160004]
# 供回水温差: 3.496705389453524
# Cost: 2.1038035694565957
# 总冷量： 1171.5895173823833
# 室温： 22.765261896533016
# 螺杆功率： 181.55632603502346 181.55632603502346
# 磁悬浮功率： 42.052038927869425 48.38228083149954
# 水泵功率： 17.50138867759955
# 总功率： 506.05113786221455
# 滚动次数： 5
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4934943578881189
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.01330933  14.5        110.          70.        ]
# 供回水温差: 3.4866906684963457
# Cost: 2.053581676799518
# 总冷量： 1172.594772542715
# 室温： 22.76035281638557
# 螺杆功率： 178.61836645278999 178.61836645278999
# 磁悬浮功率： 41.272513267209064 49.94944262065466
# 水泵功率： 17.02000000000004
# 总功率： 499.51868879344386
# 滚动次数： 6
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.49377193254324536
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.36828676  14.5        110.          64.16922735]
# 供回水温差: 3.1317132432796697
# Cost: 2.0358624361844235
# 总冷量： 1172.6200089538097
# 室温： 22.7527910348572
# 螺杆功率： 180.03022572555554 180.03022572555554
# 磁悬浮功率： 41.598555217611256 48.19033615509556
# 水泵功率： 15.661487992085483
# 总功率： 496.83380680007434
# 滚动次数： 7
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.49414758700070105
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.05349418  14.5        110.          69.50095189]
# 供回水温差: 3.446505816864711
# Cost: 2.0407503123684325
# 总冷量： 1171.9184735703468
# 室温： 22.743453198699314
# 螺杆功率： 177.8692114656271 177.8692114656271
# 磁悬浮功率： 41.06478575065294 49.42699008895657
# 水泵功率： 16.875581543153714
# 总功率： 496.85694340032484
# 滚动次数： 8
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.46072121116731496
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.94722754  14.5        110.47821533  70.        ]
# 供回水温差: 2.5527724636223397
# Cost: 2.0433945753684104
# 总冷量： 1170.5889156937599
# 室温： 22.736756179848737
# 螺杆功率： 177.4708933503574 177.4708933503574
# 磁悬浮功率： 40.98278056354494 49.337109290630714
# 水泵功率： 17.163333149568416
# 总功率： 496.7516760035957
# 滚动次数： 9
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.3889246329360774
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.10727295  14.55999006 110.          68.74777095]
# 供回水温差: 3.4527171132182684
# Cost: 2.0856127366958854
# 总冷量： 1168.3457246100902
# 室温： 22.73845684036318
# 螺杆功率： 181.17904713002503 181.17904713002503
# 磁悬浮功率： 41.189703860957934 48.59586222891764
# 水泵功率： 16.667596616441756
# 总功率： 502.1464501992509
# 最终优化结果：
# Tsupply(t+1)，Treturn(t+1),Volume(t+1): [array([ 11.4283606 ,  14.50063856, 110.        ,  64.48543037]), array([ 11.2129626 ,  14.5       , 110.65434249,  57.29759279]), array([ 11.26519754,  14.5       , 110.71534291,  50.85103161]), array([ 11.44706849,  14.5       , 110.        ,  65.33573732]), array([ 11.00329461,  14.5       , 115.3760857 ,  66.17160004]), array([ 11.01330933,  14.5       , 110.        ,  70.        ]), array([ 11.36828676,  14.5       , 110.        ,  64.16922735]), array([ 11.05349418,  14.5       , 110.        ,  69.50095189]), array([ 11.94722754,  14.5       , 110.47821533,  70.        ]), array([ 11.10727295,  14.55999006, 110.        ,  68.74777095])]
# 代价函数最优值： [2.0826880167100237, 2.0944965094873313, 2.126033070676753, 2.0607508653321616, 2.1038035694565957, 2.053581676799518, 2.0358624361844235, 2.0407503123684325, 2.0433945753684104, 2.0856127366958854]
# 冷量变化： [1168.0832257401944, 1170.2120371210574, 1169.8311103868484, 1169.8316630613804, 1171.5895173823833, 1172.594772542715, 1172.6200089538097, 1171.9184735703468, 1170.5889156937599, 1168.3457246100902]
# 室温： [22.790162760105268, 22.78499894380837, 22.78017499538697, 22.7761015451533, 22.765261896533016, 22.76035281638557, 22.7527910348572, 22.743453198699314, 22.736756179848737, 22.73845684036318]
# 供回水温差变化： [3.0722779551039388, 3.2870374027489113, 3.2348024589388107, 3.0529315075021817, 3.496705389453524, 3.4866906684963457, 3.1317132432796697, 3.446505816864711, 2.5527724636223397, 3.4527171132182684]
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.30313081046094226
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.42571791  14.5        121.06651494  55.43827559]
# Cost: 2.033587325960405
# 总冷量： 1166.3927845531703
# 室温： 22.73569124490235
# 螺杆功率： 180.58395799069277 180.58395799069277
# 磁悬浮功率： 41.478610196749024 44.44092009300594
# 水泵功率： 16.119301584358936
# 总功率： 495.4453510242173
# 滚动次数： 155
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.2411738195523867
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.15665864  14.5        110.          58.5323537 ]
# Cost: 1.957206104640087
# 总冷量： 1164.5811951947212
# 室温： 22.732654289755054
# 螺杆功率： 177.18557832156557 177.18557832156557
# 磁悬浮功率： 40.79772538858692 45.24192324585868
# 水泵功率： 15.031917778201318
# 总功率： 485.5065586121807
# 滚动次数： 156
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.21110560027116917
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.65701071  14.5        110.          67.99552947]
# Cost: 1.942390212078446
# 总冷量： 1162.522964658141
# 室温： 22.727441745368836
# 螺杆功率： 173.43427821011463 173.43427821011463
# 磁悬浮功率： 39.96253749075534 46.98503037525576
# 水泵功率： 16.471849825265508
# 总功率： 483.23167376203685
# 滚动次数： 157
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.1859574695962806
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.74855157  14.54825623 114.67095483  43.5047405 ]
# Cost: 2.0642270741762405
# 总冷量： 1160.880554715991
# 室温： 22.731908675770683
# 螺杆功率： 183.4710336753898 183.4710336753898
# 磁悬浮功率： 41.27314087850294 43.94630306062404
# 水泵功率： 15.627303348821101
# 总功率： 499.0434213363699
# 滚动次数： 158
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.16950797483911656
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.58284178  14.5        110.          55.84264656]
# Cost: 1.906111238080214
# 总冷量： 1160.5867501834034
# 室温： 22.73897531733459
# 螺杆功率： 175.21717498512783 175.21717498512783
# 磁悬浮功率： 40.19629522627775 43.78367894573176
# 水泵功率： 14.96841079651091
# 总功率： 479.3195565317979
# 滚动次数： 159
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.13203133950200224
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.32873332  14.5        129.34532087  42.2387386 ]
# Cost: 2.012495624974376
# 总冷量： 1160.026229946017
# 室温： 22.74288813394207
# 螺杆功率： 181.19916394083813 181.19916394083813
# 磁悬浮功率： 40.50148792886645 44.48545110877511
# 水泵功率： 15.289306282743269
# 总功率： 493.2531857675476
# 滚动次数： 160
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.1288230029560779
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.98470056  14.5        110.          54.82486563]
# Cost: 1.8797443580465754
# 总冷量： 1159.2315922310947
# 室温： 22.75315070438942
# 螺杆功率： 174.35988220446987 174.35988220446987
# 磁悬浮功率： 39.92343417564431 43.21759728696923
# 水泵功率： 14.984294154522047
# 总功率： 476.81367833511945
# 滚动次数： 161
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.1643734240537853
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.          14.55187251 110.          61.17588431]
# Cost: 1.8981593186622796
# 总冷量： 1159.9499154025316
# 室温： 22.755601675237617
# 螺杆功率： 175.00202964713097 175.00202964713097
# 磁悬浮功率： 39.63563418918487 44.0083150388191
# 水泵功率： 15.243466097406326
# 总功率： 479.37840681448483
# 滚动次数： 162
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.1826328139817136
# 供温，回温，螺杆流量，磁悬浮流量: [ 12.   14.5 110.   70. ]
# Cost: 1.8615888276270853
# 总冷量： 1161.3114685887099
# 室温： 22.756908504512527
# 螺杆功率： 169.35335909174378 169.35335909174378
# 磁悬浮功率： 38.84397356982178 46.059697200508545
# 水泵功率： 17.02000000000004
# 总功率： 474.670388953818
# 滚动次数： 163
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.20381083009726525
# 供温，回温，螺杆流量，磁悬浮流量: [ 12.          14.5        110.          62.38827868]
# Cost: 1.88094232498954
# 总冷量： 1162.6282778668403
# 室温： 22.763238783130443
# 螺杆功率： 173.33121572418364 173.33121572418364
# 磁悬浮功率： 39.799524158031474 44.97775988025274
# 水泵功率： 15.38993792895576
# 总功率： 477.6095292735188
# 滚动次数： 164
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.23859239922391992
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.40656394  14.5        110.          64.20728152]
# Cost: 1.905130946056347
# 总冷量： 1163.9751648414135
# 室温： 22.775056214770938
# 螺杆功率： 174.22655973723818 174.22655973723818
# 磁悬浮功率： 40.0809884492955 45.93503830345566
# 水泵功率： 15.668022502000156
# 总功率： 481.47321373322796
# 滚动次数： 165
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.2557224718682136
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.59266217  14.5        125.18659166  53.87335667]
# Cost: 2.035478648950222
# 总冷量： 1165.2611667013168
# 室温： 22.800812436003927
# 螺杆功率： 181.61977714776847 181.61977714776847
# 磁悬浮功率： 41.65200888660405 44.326534444815806
# 水泵功率： 16.7523456591623
# 总功率： 499.4751346044437
# 滚动次数： 166
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.27244419089644367
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.          14.5        110.          56.97279261]
# Cost: 1.9661392638878554
# 总冷量： 1166.1331830376387
# 室温： 22.8162190611259
# 螺杆功率： 179.68238200346337 179.68238200346337
# 磁悬浮功率： 41.466804421348755 45.71187759511847
# 水泵功率： 14.97645113389865
# 总功率： 491.47279942508993
# 滚动次数： 167
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.35197193318477815
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.83683145  14.52786259 120.87949214  57.00150249]
# Cost: 2.08239946895446
# 总冷量： 1167.760255663395
# 室温： 22.82399184270281
# 螺杆功率： 184.5639724626839 184.5639724626839
# 磁悬浮功率： 42.33600726013059 45.59357433400813
# 水泵功率： 16.443095917576784
# 总功率： 506.38681427223685
# 滚动次数： 168
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.40138575546350663
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.68094055  14.5        110.91965438  70.        ]
# Cost: 2.02597684382874
# 总冷量： 1169.8793737071753
# 室温： 22.837459630026864
# 螺杆功率： 178.54098064300766 178.54098064300766
# 磁悬浮功率： 41.305720667947405 49.657212015633924
# 水泵功率： 17.29993779573863
# 总功率： 499.94470735681256
# 滚动次数： 169
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4042928245896789
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.57986453  14.5        115.98408895  65.56647191]
# Cost: 2.076274858297437
# 总冷量： 1170.4805232983826
# 室温： 22.843426488192208
# 螺杆功率： 181.8141132265516 181.8141132265516
# 磁悬浮功率： 42.1363580535079 48.1570714156601
# 水泵功率： 17.50233010425984
# 总功率： 506.4286462350507
# 滚动次数： 170
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.42362596925123486
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.76322297  14.5        110.          65.90104376]
# Cost: 2.038093958132897
# 总冷量： 1171.293910676241
# 室温： 22.849000540615943
# 螺杆功率： 181.28647650861342 181.28647650861342
# 磁悬浮功率： 42.02432613777051 49.34105481667719
# 水泵功率： 15.989896151470418
# 总功率： 501.9080224260858
# 滚动次数： 171
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.46781410514328314
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.          14.60495225 116.25848769  53.53814655]
# Cost: 2.2020658571653065
# 总冷量： 1171.7567636340857
# 室温： 22.85381725203994
# 螺杆功率： 193.15694181644253 193.15694181644253
# 磁悬浮功率： 43.713293626536576 46.72760823260748
# 水泵功率： 15.114646628204468
# 总功率： 522.0987253766425
# 滚动次数： 172
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4601421716947371
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.52644221  14.5        110.          70.        ]
# Cost: 2.0876754007885703
# 总冷量： 1171.803511286378
# 室温： 22.858010177401805
# 螺杆功率： 181.89104323492452 181.89104323492452
# 磁悬浮功率： 42.238880092293364 51.28829543596218
# 水泵功率： 17.02000000000004
# 总功率： 508.3692619981047
# 滚动次数： 173
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.49528694431105863
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.17215962  14.5        132.12486935  42.95814754]
# Cost: 2.2957248840312805
# 总冷量： 1172.7613632410764
# 室温： 22.863291436308476
# 螺杆功率： 195.66560082868446 195.66560082868446
# 磁悬浮功率： 44.708658118016736 49.98631681650116
# 水泵功率： 15.826864979824961
# 总功率： 533.5067715313617
# 滚动次数： 174
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.49545152287133903
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.          14.5        110.          46.09744859]
# Cost: 2.2426653175219755
# 总冷量： 1172.7657068800927
# 室温： 22.856903600464403
# 螺杆功率： 192.99159132895153 192.99159132895153
# 磁悬浮功率： 44.905055107633125 48.09367539010031
# 水泵功率： 16.020137401753004
# 总功率： 527.0423253608956
# 滚动次数： 175
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.45443298047195957
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.43240061  14.5        130.98762509  53.17048636]
# Cost: 2.329299469065952
# 总冷量： 1171.9482330602407
# 室温： 22.868276378666152
# 螺杆功率： 194.31183281199478 194.31183281199478
# 磁悬浮功率： 45.2270115913259 48.44610066262564
# 水泵功率： 18.428145462837165
# 总功率： 537.5812142664525
# 滚动次数： 176
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4338070182047147
# 供温，回温，螺杆流量，磁悬浮流量: [ 12.          14.5        111.50125128  63.81848113]
# Cost: 2.172863190917145
# 总冷量： 1171.0750228512286
# 室温： 22.869334051978548
# 螺杆功率： 188.28287392276687 188.28287392276687
# 磁悬浮功率： 44.04581205286734 50.87926039356965
# 水泵功率： 15.872586364528388
# 总功率： 519.1085793855559
# 滚动次数： 177
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4295277560654128
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.97045166  14.50748343 110.          58.31996121]
# Cost: 2.1987203872192422
# 总冷量： 1170.2087402141094
# 室温： 22.871902305298704
# 螺杆功率： 191.20362364917315 191.20362364917315
# 磁悬浮功率： 44.73062156641647 50.09012312526602
# 水泵功率： 15.021337319302575
# 总功率： 522.2920039479366
# 滚动次数： 178
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4088180265114218
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.98648614  14.58426122 110.          64.55220867]
# Cost: 2.293507703738783
# 总冷量： 1169.5565926402808
# 室温： 22.87551466949017
# 螺杆功率： 195.163373261323 195.163373261323
# 磁悬浮功率： 44.65981978440852 51.44851581334644
# 水泵功率： 15.728649329638415
# 总功率： 533.6210301093162
# 滚动次数： 179
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4016612095356479
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.48303684  14.5        110.          53.21589402]
# Cost: 2.2521259695526705
# 总冷量： 1169.5978015846015
# 室温： 22.881115797522913
# 螺杆功率： 194.14837366808013 194.14837366808013
# 磁悬浮功率： 45.62572403794608 49.828311795004524
# 水泵功率： 15.054109163526789
# 总功率： 528.9131106596913
# 滚动次数： 180
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4519732110941078
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.80826347  14.5        110.          60.96191703]
# Cost: 2.2348771130127965
# 总冷量： 1170.830341155529
# 室温： 22.87709202696673
# 螺杆功率： 192.18046962867595 192.18046962867595
# 磁悬浮功率： 45.17628738521906 51.555740848124906
# 水泵功率： 15.220844556831253
# 总功率： 526.7555011611896
# 滚动次数： 181
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4642457724775809
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.66698687  14.5        113.04198301  61.31380121]
# Cost: 2.2850666387919727
# 总冷量： 1172.47804217875
# 室温： 22.874731447755885
# 螺杆功率： 194.0515616393287 194.0515616393287
# 磁悬浮功率： 45.673598640802595 51.75033526715744
# 水泵功率： 15.693815834592897
# 总功率： 532.6085046903961
# 滚动次数： 182
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4742864108525182
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.9785252   14.55592948 110.          54.19094763]
# Cost: 2.390890164277592
# 总冷量： 1173.2964275527
# 室温： 22.87533951567557
# 螺杆功率： 201.10579036353852 201.10579036353852
# 磁悬浮功率： 46.67398762944916 51.00116473961397
# 水泵功率： 15.005262371202718
# 总功率： 544.9025202097482
# 滚动次数： 183
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.52981960408178
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.3277776   14.58997293 110.          70.        ]
# Cost: 2.4556528738212435
# 总冷量： 1174.824931513071
# 室温： 22.87450084930246
# 螺杆功率： 200.13799215364543 200.13799215364543
# 磁悬浮功率： 45.725561755549805 55.195523040368435
# 水泵功率： 17.02000000000004
# 总功率： 552.2570691032092
# 滚动次数： 184
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.5598855150417137
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.32057186  14.5        110.          47.34853052]
# Cost: 2.374384747936312
# 总冷量： 1176.5430076229572
# 室温： 22.865452188162937
# 螺杆功率： 199.18534792908474 199.18534792908474
# 磁悬浮功率： 46.763094115104025 50.259075998363144
# 水泵功率： 15.772709151745914
# 总功率： 542.7109934268744
# 滚动次数： 185
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.574561607689185
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.65434644  14.5        110.          60.39935697]
# Cost: 2.2333747300105697
# 总冷量： 1177.9648382210733
# 室温： 22.861463943565074
# 螺杆功率： 192.1353881576207 192.1353881576207
# 磁悬浮功率： 44.990336632752886 51.33295591487274
# 水泵功率： 15.165989119958851
# 总功率： 526.0920362227436
# 滚动次数： 186
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.5935103940738045
# 供温，回温，螺杆流量，磁悬浮流量: [ 12.         14.5       122.9580052  52.3410966]
# Cost: 2.280655333413823
# 总冷量： 1177.7591786968708
# 室温： 22.857311335977673
# 螺杆功率： 194.88711500540484 194.88711500540484
# 磁悬浮功率： 45.425275170455436 48.73686203501295
# 水泵功率： 15.868554425919456
# 总功率： 531.5420304940365
# 滚动次数： 187
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.6177673040305919
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.07948381  14.64975582 115.21918088  53.14211297]
# Cost: 2.3684492354795736
# 总冷量： 1178.4286326396466
# 室温： 22.847146230947693
# 螺杆功率： 201.31782396613193 201.31782396613193
# 磁悬浮功率： 45.31318594086317 48.40122649446155
# 水泵功率： 15.023321540761401
# 总功率： 541.4200249898727
# 滚动次数： 188
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.6058302359730675
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.15132259  14.5        116.80808703  55.41692797]
# Cost: 2.2159662373284874
# 总冷量： 1178.7500427865982
# 室温： 22.825249183233776
# 螺杆功率： 191.64113147852476 191.64113147852476
# 磁悬浮功率： 44.65234929534059 48.62506437701235
# 水泵功率： 15.368401896314708
# 总功率： 522.6648823183466
# 滚动次数： 189
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.5872905871674504
# 供温，回温，螺杆流量，磁悬浮流量: [ 12.          14.5        110.          63.29548159]
# Cost: 2.1536016530313753
# 总冷量： 1177.8230736148357
# 室温： 22.81133892280892
# 螺杆功率： 186.97173281193812 186.97173281193812
# 磁悬浮功率： 43.5076112852707 50.528999729413826
# 水泵功率： 15.519879017753567
# 总功率： 514.5397136918215
# 滚动次数： 190
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.6277988254637876
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.20797291  14.5        120.41062016  38.81405721]
# Cost: 2.3251423251043195
# 总冷量： 1177.6530747568606
# 室温： 22.820935366139967
# 螺杆功率： 196.83980951061454 196.83980951061454
# 磁悬浮功率： 44.948059493751714 50.36401295668423
# 水泵功率： 15.463722230436133
# 总功率： 535.3828581629734
# 滚动次数： 191
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.6008793647929564
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.32703628  14.5        110.          69.48527606]
# Cost: 2.134502785764644
# 总冷量： 1177.8321628379822
# 室温： 22.82885048559772
# 螺杆功率： 183.88902452332596 183.88902452332596
# 磁悬浮功率： 42.668289601277415 51.92307462366664
# 水泵功率： 16.871130495577006
# 总功率： 512.982804758327
# 滚动次数： 192
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.5487172759642462
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.38294248  14.5        110.          70.        ]
# Cost: 2.1242710598699857
# 总冷量： 1175.7158524286747
# 室温： 22.827686801051872
# 螺杆功率： 183.1431585352052 183.1431585352052
# 磁悬浮功率： 42.50761179686241 51.831943870210075
# 水泵功率： 17.02000000000004
# 总功率： 511.685872737483
# 滚动次数： 193
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.5550111736684655
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.          14.5        110.          44.07608099]
# Cost: 2.196916728600686
# 总冷量： 1173.5502475184203
# 室温： 22.83097156022897
# 螺杆功率： 190.16138032432272 190.16138032432272
# 磁悬浮功率： 43.902275227302994 46.92351876799706
# 水泵功率： 16.489876276845905
# 总功率： 520.6181834744832
# 滚动次数： 194
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.5261756218691417
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.35396175  14.5        130.46723793  58.19837342]
# Cost: 2.2167102587390537
# 总冷量： 1172.9611491030455
# 室温： 22.820266334985988
# 螺杆功率： 186.16492296361187 186.16492296361187
# 磁悬浮功率： 42.98973436901092 46.11969486879181
# 水泵功率： 20.367781974526622
# 总功率： 522.5426210886064
# 滚动次数： 195
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4918333466544823
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.8330283   14.5        119.20724577  61.27797044]
# Cost: 2.0581828693454938
# 总冷量： 1171.7836508911848
# 室温： 22.79651571670143
# 螺杆功率： 181.30950367892527 181.30950367892527
# 磁悬浮功率： 41.82558672149446 46.15179228506209
# 水泵功率： 17.165467417249886
# 总功率： 502.0927886161567
# 滚动次数： 196
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4799041937641334
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.75393153  14.5        116.89117172  58.4487387 ]
# Cost: 1.9972033079963298
# 总冷量： 1170.3455905628205
# 室温： 22.78772204423637
# 螺杆功率： 179.88186352575278 179.88186352575278
# 磁悬浮功率： 41.377677668665704 45.210474444692494
# 水泵功率： 15.876538559800053
# 总功率： 493.981494844264
# 滚动次数： 197
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.47177608312512687
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.37717996  14.5        113.41239561  55.29266566]
# Cost: 1.9458699567146478
# 总冷量： 1169.541819961071
# 室温： 22.78254536764111
# 螺杆功率： 178.4061808694593 178.4061808694593
# 磁悬浮功率： 40.89866174019028 44.323363877967566
# 水泵功率： 15.041224833919216
# 总功率： 487.15806185883406
# 滚动次数： 198
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.4099446639262695
# 供温，回温，螺杆流量，磁悬浮流量: [ 12.          14.5        120.23958908  48.37115932]
# Cost: 1.9618120661069272
# 总冷量： 1168.5052980166674
# 室温： 22.776910857033112
# 螺杆功率： 179.83723108582163 179.83723108582163
# 磁悬浮功率： 40.84020941974206 43.25898487657567
# 水泵功率： 15.036064189878402
# 总功率： 488.88184903759617
# 滚动次数： 199
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.35374482765563753
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.          14.5        131.48096969  35.        ]
# Cost: 2.073702610051401
# 总冷量： 1166.2388623034954
# 室温： 22.77223043520787
# 螺杆功率： 184.30073283801647 184.30073283801647
# 磁悬浮功率： 40.11769983342019 49.09254523782918
# 水泵功率： 14.969631289315146
# 总功率： 502.7206046152278
# 滚动次数： 200
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.33268088633050896
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.0762643   14.51417547 110.          57.29436006]
# Cost: 1.8633895723885703
# 总冷量： 1164.0296846288443
# 室温： 22.763103442040286
# 螺杆功率： 173.7518680579839 173.7518680579839
# 磁悬浮功率： 39.55884153574074 43.2849876782803
# 水泵功率： 14.983676859263142
# 总功率： 475.2985959077783
# 滚动次数： 201
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.2569284194995959
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.69026729  14.5        110.          70.        ]
# Cost: 1.8312844087724311
# 总冷量： 1162.4351779311894
# 室温： 22.75216288811919
# 螺杆功率： 167.76583527957195 167.76583527957195
# 磁悬浮功率： 38.359808567269155 45.40233266489179
# 水泵功率： 17.02000000000004
# 总功率： 470.35381179130496
# 滚动次数： 202
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.22866745074411765
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.94760979  14.5        110.          50.56580962]
# Cost: 1.8624826774229322
# 总冷量： 1161.4178524547815
# 室温： 22.75044537309973
# 螺杆功率： 173.559014504801 173.559014504801
# 磁悬浮功率： 39.437286168724974 41.94796450899063
# 水泵功率： 15.28848905121373
# 总功率： 474.3687468409588
# 滚动次数： 203
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.1923154570329359
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.62383132  14.5        112.51881701  62.17455605]
# Cost: 1.8086067569851774
# 总冷量： 1160.2659040755034
# 室温： 22.755020818428168
# 螺杆功率： 169.34891456977806 169.34891456977806
# 磁悬浮功率： 38.61838874724573 42.94026256268219
# 水泵功率： 15.75418721198838
# 总功率： 467.51904208544914
# 滚动次数： 204
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.1653729708903356
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.         14.5       110.         64.9914385]
# Cost: 1.778215221258794
# 总冷量： 1159.63011841923
# 室温： 22.755281307220656
# 螺杆功率： 167.22994646641297 167.22994646641297
# 磁悬浮功率： 38.13467824822341 43.43250642843161
# 水泵功率： 15.809494714630489
# 总功率： 463.4555617533724
# 滚动次数： 205
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.15839106431783137
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.72746402  14.57620187 119.36244794  50.77009508]
# Cost: 1.8910384547233725
# 总冷量： 1159.7296955361962
# 室温： 22.750772805657984
# 螺杆功率： 176.2099270236227 176.2099270236227
# 磁悬浮功率： 39.20212741228012 41.08871183160483
# 水泵功率： 15.142312735675375
# 总功率： 478.13763149815645
# 滚动次数： 206
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.16447171658262788
# 供温，回温，螺杆流量，磁悬浮流量: [ 12.          14.51548463 114.19704508  68.3059605 ]
# Cost: 1.8165230529511018
# 总冷量： 1159.3498245060443
# 室温： 22.75381382892169
# 螺杆功率： 166.9632969265868 166.9632969265868
# 磁悬浮功率： 37.89041854932482 43.208572834519806
# 水泵功率： 17.823822482024525
# 总功率： 468.4970526830918
# 滚动次数： 207
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.17762129492705298
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.43953906  14.5        110.          57.41133125]
# Cost: 1.7676131319172659
# 总冷量： 1159.476197963953
# 室温： 22.7544068870008
# 螺杆功率： 168.53119677864112 168.53119677864112
# 磁悬浮功率： 38.26712106947883 41.67553002650009
# 水泵功率： 14.986847841908002
# 总功率： 461.9655881789852
# 滚动次数： 208
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.1423525110161833
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.91705117  14.73208166 110.          53.70894166]
# Cost: 1.9269137902123115
# 总冷量： 1159.0300496536493
# 室温： 22.7558457129492
# 螺杆功率： 179.26340812072422 179.26340812072422
# 磁悬浮功率： 38.96923824825113 40.55147107970253
# 水泵功率： 15.026895363672168
# 总功率： 483.1282116604186
# 滚动次数： 209
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.11327497405262363
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.20424615  14.52053639 110.          60.13856385]
# Cost: 1.7497430176292246
# 总冷量： 1158.104762430787
# 室温： 22.758149295416242
# 螺杆功率： 167.4678057456701 167.4678057456701
# 磁悬浮功率： 37.83466017279897 41.5908251920682
# 水泵功率： 15.142830398935018
# 总功率： 459.78958805301244
# 滚动次数： 210
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.11997688685594454
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.64860014  14.5        110.          69.99821218]
# Cost: 1.7278949545944267
# 总冷量： 1157.4931203973292
# 室温： 22.757679623523494
# 螺杆功率： 162.71282590281405 162.71282590281405
# 磁悬浮功率： 37.00322339745338 43.291680607603325
# 水泵功率： 17.019473221625617
# 总功率： 456.77897547556165
# 滚动次数： 211
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.10866318229988821
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.32341215  14.5        110.          61.28756595]
# Cost: 1.721093100268079
# 总冷量： 1157.356233562529
# 室温： 22.744501654848637
# 螺杆功率： 165.13585776561408 165.13585776561408
# 磁悬浮功率： 37.44255263615823 41.465761938986674
# 水泵功率： 15.255658264010378
# 总功率： 454.94700489840426
# 滚动次数： 212
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.09708451485835781
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.0649845   14.5        110.          59.50013708]
# Cost: 1.7168017878449984
# 总冷量： 1157.1482873773575
# 室温： 22.74483589942317
# 螺杆功率： 165.32054347563664 165.32054347563664
# 磁悬浮功率： 37.43427721152055 41.02857206692702
# 水泵功率： 15.092209942853856
# 总功率： 454.3805660582824
# 滚动次数： 213
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.08243224946387784
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.00065835  14.5        113.25085987  55.90160609]
# Cost: 1.7291097953631156
# 总冷量： 1156.9480508224665
# 室温： 22.74858050665399
# 螺杆功率： 166.65475818252997 166.65475818252997
# 磁悬浮功率： 37.6104207459296 40.20552585804688
# 水泵功率： 15.06826978080943
# 总功率： 456.33027231146474
# 滚动次数： 214
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.07587574739835219
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.          14.5        110.          54.77925894]
# Cost: 1.7146636481085398
# 总冷量： 1157.2827541676163
# 室温： 22.754531708268352
# 螺杆功率： 166.112124343959 166.112124343959
# 磁悬浮功率： 37.46387004222018 40.109303148178896
# 水泵功率： 14.985518883410293
# 总功率： 454.753978528548
# 滚动次数： 215
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.056951259076595304
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.90127405  14.5        111.58299604  57.3414013 ]
# Cost: 1.7052699356180931
# 总冷量： 1157.6300392322241
# 室温： 22.74604081945635
# 螺杆功率： 165.1486514474144 165.1486514474144
# 磁悬浮功率： 37.248998962923025 40.16808595118936
# 水泵功率： 15.053954233219088
# 总功率： 452.87625050859845
# 滚动次数： 216
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.06610290204997823
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.          14.5        117.97780664  59.06701515]
# Cost: 1.72988259877151
# 总冷量： 1157.5222841471434
# 室温： 22.745919767586596
# 螺杆功率： 165.2369161981324 165.2369161981324
# 磁悬浮功率： 37.20959423037214 39.84371858527072
# 水泵功率： 16.241584047792287
# 总功率： 456.25189735528454
# 滚动次数： 217
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.09430037356679435
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.74335021  14.5        110.          61.75922224]
# Cost: 1.6737297235886124
# 总冷量： 1157.5486949916183
# 室温： 22.751185135894712
# 螺杆功率： 162.75513960020007 162.75513960020007
# 磁悬浮功率： 36.75142347944355 40.670764486090725
# 水泵功率： 15.310058797566967
# 总功率： 448.8626435586353
# 滚动次数： 218
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.07955645060637266
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.93617271  14.5        110.          57.15283446]
# Cost: 1.6849825141022545
# 总冷量： 1157.8023265455663
# 室温： 22.743469132411896
# 螺杆功率： 164.04822477899395 164.04822477899395
# 磁悬浮功率： 36.943741974500306 39.90452261043408
# 水泵功率： 14.980227205525068
# 总功率： 449.8853957594975
# 滚动次数： 219
# Stopping search: Swarm best objective change less than 0.1
# 更新后的Cooling： 0.10624555918890621
# 供温，回温，螺杆流量，磁悬浮流量: [ 11.97148364  14.5        110.          57.05643819]
# Cost: 1.6743293409310775
# 总冷量： 1158.4278279097377
# 室温： 22.755864387482074
# 螺杆功率： 163.83730472790475 163.83730472790475
# 磁悬浮功率： 36.86473955653325 39.79341876814856
# 水泵功率： 14.978120167684892
# 总功率： 449.267128283546
# 最终优化结果：
# Tsupply(t+1)，Treturn(t+1),Volume(t+1): [array([ 11.42662473,  14.5       , 111.8233335 ,  58.9176858 ]), array([ 11.03873324,  14.5       , 111.87353189,  45.17801531]), array([ 12.        ,  14.5       , 110.42789067,  62.31093029]), array([ 11.4612809 ,  14.5       , 110.        ,  60.44720684]), array([ 11.35615481,  14.5       , 120.01358124,  43.96521631]), array([ 11.32431628,  14.5       , 110.        ,  55.73767459]), array([ 11.44566743,  14.5       , 110.        ,  56.73055174]), array([ 11.83464663,  14.5       , 110.        ,  48.64092951]), array([ 11.89376617,  14.5       , 119.32359975,  59.49170529]), array([ 11.03555998,  14.52926482, 110.        ,  53.62723017]), array([ 11.00421413,  14.5       , 122.08793577,  57.67835973]), array([ 11.98747713,  14.5632999 , 110.        ,  67.18746105]), array([ 11.72512467,  14.5       , 110.        ,  64.5300462 ]), array([ 11.        ,  14.5       , 110.        ,  65.04939132]), array([ 11.55167981,  14.5       , 110.        ,  58.95526205]), array([ 12.        ,  14.5       , 110.        ,  56.22365911]), array([ 11. ,  14.5, 110. ,  70. ]), array([ 11.57851268,  14.5       , 110.        ,  45.09782215]), array([ 11.59750051,  14.5       , 110.        ,  46.69841529]), array([ 12.        ,  14.52704756, 125.07903564,  52.30303951]), array([ 12.        ,  14.54927005, 110.        ,  58.4169765 ]), array([ 11.90229216,  14.5       , 110.        ,  68.1253822 ]), array([ 12.        ,  14.51453599, 110.        ,  54.91212137]), array([ 11.23155775,  14.5       , 110.        ,  70.        ]), array([ 11.72652701,  14.5       , 127.13451798,  48.05916445]), array([ 12.        ,  14.5       , 110.1092489 ,  48.76342114]), array([ 11.37652961,  14.58946666, 111.14771191,  68.02730653]), array([ 11.20291081,  14.5       , 110.        ,  70.        ]), array([ 11.19000539,  14.52853233, 118.32728224,  54.83195488]), array([ 11.37114689,  14.53229668, 110.        ,  60.59115307]), array([ 12.        ,  14.62392774, 110.        ,  49.78369065]), array([ 11.02549279,  14.5       , 114.90140906,  45.00261909]), array([ 11.42788393,  14.5       , 111.59810258,  61.05140332]), array([ 11.73552318,  14.5       , 111.79072805,  67.67141762]), array([ 11.69603323,  14.5       , 110.        ,  62.98964603]), array([ 11.60638752,  14.5       , 110.        ,  70.        ]), array([ 11.54103169,  14.
567194589358, 22.758589735998626, 22.74946797810576, 22.74490947658996, 22.74176704605498, 22.73569124490235, 22.732654289755054, 22.727441745368836, 22.731908675770683, 22.73897531733459, 22.74288813394207, 22.75315070438942, 22.755601675237617, 22.756908504512527, 22.763238783130443, 22.775056214770938, 22.800812436003927, 22.8162190611259, 22.82399184270281, 22.837459630026864, 22.843426488192208, 22.849000540615943, 22.85381725203994, 22.858010177401805, 22.863291436308476, 22.856903600464403, 22.868276378666152, 22.869334051978548, 22.871902305298704, 22.87551466949017, 22.881115797522913, 22.87709202696673, 22.874731447755885, 22.87533951567557, 22.87450084930246, 22.865452188162937, 22.861463943565074, 22.857311335977673, 22.847146230947693, 22.825249183233776, 22.81133892280892, 22.820935366139967, 22.82885048559772, 22.827686801051872, 22.83097156022897, 22.820266334985988, 22.79651571670143, 22.78772204423637, 22.78254536764111, 22.776910857033112, 22.77223043520787, 22.763103442040286, 22.75216288811919, 22.75044537309973, 22.7550208184 ...

# %%
water1 = [arr[0] for arr in x]
water2 = [arr[1] for arr in x]
water3 = [arr[2] for arr in x]
water4 = [arr[3] for arr in x]

result = {'Supply': water1, 'Return': water2, 'Vscrew': water3, 'Vmaglev': water4,
              'Cooling': co, 'Temp': tin, 'Pscrew1': sc1, 'Pscrew2': sc2, 'Pmaglev1': ma1, 'Pmaglev2': ma2, 'Ppump': pu,
              'Total_power': tot}
re = pd.DataFrame(result)
print(re)
#re.to_csv('1121_GZZ_output1.csv', index=False)
# Out:
#       Supply     Return      Vscrew    Vmaglev      Cooling       Temp  \
# 0  11.428361  14.500639  110.000000  64.485430  1168.083226  22.790163
# 1  11.212963  14.500000  110.654342  57.297593  1170.212037  22.784999
# 2  11.265198  14.500000  110.715343  50.851032  1169.831110  22.780175
# 3  11.447068  14.500000  110.000000  65.335737  1169.831663  22.776102
# 4  11.003295  14.500000  115.376086  66.171600  1171.589517  22.765262
# 5  11.013309  14.500000  110.000000  70.000000  1172.594773  22.760353
# 6  11.368287  14.500000  110.000000  64.169227  1172.620009  22.752791
# 7  11.053494  14.500000  110.000000  69.500952  1171.918474  22.743453
# 8  11.947228  14.500000  110.478215  70.000000  1170.588916  22.736756
# 9  11.107273  14.559990  110.000000  68.747771  1168.345725  22.738457
#
#       Pscrew1     Pscrew2   Pmaglev1   Pmaglev2      Ppump  Total_power
# 0  182.870730  182.870730  42.531545  49.385810  15.716715   504.808962
# 1  185.139545  185.139545  43.016809  47.686265  15.005263   505.997953
# 2  186.988333  186.988333  43.365302  46.731651  15.182539   509.621235
# 3  181.271067  181.271067  42.044803  49.111737  15.875720   501.325836
# 4  181.556326  181.556326  42.052039  48.382281  17.501389   506.051138
# 5  178.618366  178.618366  41.272513  49.949443  17.020000   499.518689
# 6  180.030226  180.030226  41.598555  48.190336  15.661488   496.833807
# 7  177.869211  177.869211  41.064786  49.426990  16.875582   496.856943
# 8  177.470893  177.470893  40.982781  49.337109  17.163333   496.751676
# 9  181.179047  181.179047  41.189704  48.595862  16.667597   502.146450
